# %% [markdown]
# Setup, Basic Libraraies, and cashing

# %%
#install FastF1
# !pip install fastf1

# Import basic libraries and enable cache
import fastf1
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')

# create a Cahce folder to speed up the repeated data fetch process
os.makedirs('fastf1_cache', exist_ok=True)

fastf1.Cache.enable_cache('fastf1_cache')
# Out:
# Requirement already satisfied: fastf1 in /usr/local/lib/python3.11/dist-packages (3.6.0)
# Requirement already satisfied: matplotlib<4.0.0,>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from fastf1) (3.10.0)
# Requirement already satisfied: numpy<3.0.0,>=1.23.1 in /usr/local/lib/python3.11/dist-packages (from fastf1) (2.0.2)
# Requirement already satisfied: pandas<3.0.0,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from fastf1) (2.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from fastf1) (2.9.0.post0)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.11/dist-packages (from fastf1) (3.13.0)
# Requirement already satisfied: requests-cache>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from fastf1) (1.2.1)
# Requirement already satisfied: requests>=2.28.1 in /usr/local/lib/python3.11/dist-packages (from fastf1) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from fastf1) (1.16.1)
# Requirement already satisfied: timple>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from fastf1) (0.1.8)
# Requirement already satisfied: websockets<14,>=10.3 in /usr/local/lib/python3.11/dist-packages (from fastf1) (13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=1.4.1->fastf1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=1.4.1->fastf1) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->fastf1) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.1->fastf1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.1->fastf1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.1->fastf1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.28.1->fastf1) (2025.8.3)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache>=1.0.0->fastf1) (25.3.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache>=1.0.0->fastf1) (25.1.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache>=1.0.0->fastf1) (4.3.8)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.11/dist-packages (from requests-cache>=1.0.0->fastf1) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from cattrs>=22.2->requests-cache>=1.0.0->fastf1) (4.14.1)

# %% [markdown]
# Load session & exploring data

# %%
# Load Canada Race session (2024)
race_2024 = fastf1.get_session(2024, 'Canada', 'R') # R = Race
race_2024.load()

print("Race loaded", race_2024.event['EventName'], "-", race_2024.event['Location'], "-", race_2024.event['EventDate'].date())

# Extract labs and View the Data structure
df_race = race_2024.laps.copy()
# View the first 5 rows
display(df_race.head())

print(f"Columns: {df_race.columns.tolist()}")
print(f"Number of laps: {df_race.shape[0]}")

#Data types and missing values
df_race.info()

#Data summary
df_race.describe()
# Out:
# core           INFO 	Loading data for Canadian Grand Prix - Race [v3.6.0]
# INFO:fastf1.fastf1.core:Loading data for Canadian Grand Prix - Race [v3.6.0]
# req            INFO 	Using cached data for session_info
# INFO:fastf1.fastf1.req:Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# INFO:fastf1.fastf1.req:Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# INFO:fastf1.fastf1.req:Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# INFO:fastf1.fastf1.req:Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# INFO:fastf1.fastf1.req:Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# INFO:fastf1.fastf1.req:Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# INFO:fastf1.fastf1.req:Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# INFO:fastf1.fastf1.core:Processing timing data...
# req            INFO 	Using cached data for car_data
# INFO:fastf1.fastf1.req:Using cached data for car_data
# req            INFO 	Using cached data for position_data
# INFO:fastf1.fastf1.req:Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# INFO:fastf1.fastf1.req:Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# INFO:fastf1.fastf1.req:Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '4', '63', '44', '81', '14', '18', '3', '10', '31', '27', '20', '77', '22', '24', '55', '23', '11', '16', '2']
# INFO:fastf1.fastf1.core:Finished loading data for 20 drivers: ['1', '4', '63', '44', '81', '14', '18', '3', '10', '31', '27', '20', '77', '22', '24', '55', '23', '11', '16', '2']
# Race loaded Canadian Grand Prix - Montréal - 2024-06-09
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:05:50.866000    VER            1 0 days 00:01:44.993000
# 1 0 days 00:07:28.538000    VER            1 0 days 00:01:37.672000
# 2 0 days 00:09:04.981000    VER            1 0 days 00:01:36.443000
# 3 0 days 00:10:40.086000    VER            1 0 days 00:01:35.105000
# 4 0 days 00:12:13.945000    VER            1 0 days 00:01:33.859000
#
#    LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 0        1.0    1.0        NaT       NaT                    NaT
# 1        2.0    1.0        NaT       NaT 0 days 00:00:28.815000
# 2        3.0    1.0        NaT       NaT 0 days 00:00:28.620000
# 3        4.0    1.0        NaT       NaT 0 days 00:00:28.103000
# 4        5.0    1.0        NaT       NaT 0 days 00:00:27.574000
#
#              Sector2Time  ... FreshTyre             Team  \
# 0 0 days 00:00:31.826000  ...      True  Red Bull Racing
# 1 0 days 00:00:31.274000  ...      True  Red Bull Racing
# 2 0 days 00:00:31.275000  ...      True  Red Bull Racing
# 3 0 days 00:00:30.649000  ...      True  Red Bull Racing
# 4 0 days 00:00:30.293000  ...      True  Red Bull Racing
#
#             LapStartTime            LapStartDate  TrackStatus  Position  \
# 0 0 days 00:04:05.608000 2024-06-09 18:03:11.605           12       2.0
# 1 0 days 00:05:50.866000 2024-06-09 18:04:56.863            1       2.0
# 2 0 days 00:07:28.538000 2024-06-09 18:06:34.535            1       2.0
# 3 0 days 00:09:04.981000 2024-06-09 18:08:10.978            1       2.0
# 4 0 days 00:10:40.086000 2024-06-09 18:09:46.083            1       2.0
#
#    Deleted  DeletedReason FastF1Generated IsAccurate
# 0    False                          False      False
# 1    False                          False       True
# 2    False                          False       True
# 3    False                          False       True
# 4    False                          False       True
#
# [5 rows x 31 columns]
# Columns: ['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint', 'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time', 'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime', 'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest', 'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime', 'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason', 'FastF1Generated', 'IsAccurate']
# Number of laps: 1272
# <class 'fastf1.core.Laps'>
# RangeIndex: 1272 entries, 0 to 1271
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                1272 non-null   timedelta64[ns]
#  1   Driver              1272 non-null   object
#  2   DriverNumber        1272 non-null   object
#  3   LapTime             1267 non-null   timedelta64[ns]
#  4   LapNumber           1272 non-null   float64
#  5   Stint               1272 non-null   float64
#  6   PitOutTime          44 non-null     timedelta64[ns]
#  7   PitInTime           45 non-null     timedelta64[ns]
#  8   Sector1Time         1250 non-null   timedelta64[ns]
#  9   Sector2Time         1270 non-null   timedelta64[ns]
#  10  Sector3Time         1267 non-null   timedelta64[ns]
#  11  Sector1SessionTime  1250 non-null   timedelta64[ns]
#  12  Sector2SessionTime  1270 non-null   timedelta64[ns]
#  13  Sector3SessionTime  1267 non-null   timedelta64[ns]
#  14  SpeedI1             1193 non-null   float64
#  15  SpeedI2             1270 non-null   float64
#  16  SpeedFL             1225 non-null   float64
#  17  SpeedST             1270 non-null   float64
#  18  IsPersonalBest      1270 non-null   object
#  19  Compound            1272 non-null   object
#  20  TyreLife            1272 non-null   float64
#  21  FreshTyre           1272 non-null   bool
#  22  Team                1272 non-null   object
#  23  LapStartTime        1272 non-null   timedelta64[ns]
#  24  LapStartDate        1270 non-null   datetime64[ns]
#  25  TrackStatus         1272 non-null   object
#  26  Position            1270 non-null   float64
#  27  Deleted             1272 non-null   bool
#  28  DeletedReason       1270 non-null   object
#  29  FastF1Generated     1272 non-null   bool
#  30  IsAccurate          1272 non-null   bool
# dtypes: bool(4), datetime64[ns](1), float64(8), object(7), timedelta64[ns](11)
# memory usage: 273.4+ KB
#                             Time                    LapTime    LapNumber  \
# count                       1272                       1267  1272.000000
# mean   0 days 00:56:21.167585691  0 days 00:01:31.457970797    33.495283
# min       0 days 00:05:49.596000     0 days 00:01:14.856000     1.000000
# 25%       0 days 00:29:51.853750     0 days 00:01:24.455000    16.000000
# 50%       0 days 00:56:31.467000     0 days 00:01:28.248000    33.000000
# 75%       0 days 01:21:12.271250     0 days 00:01:34.571000    50.000000
# max       0 days 01:50:47.328000     0 days 00:02:25.739000    70.000000
# std    0 days 00:30:17.486492435  0 days 00:00:12.611833756    19.813330
#
#              Stint                 PitOutTime                  PitInTime  \
# count  1272.000000                         44                         45
# mean      1.997642  0 days 00:56:34.737272727  0 days 01:00:02.210244444
# min       1.000000     0 days 00:04:17.809000     0 days 00:15:20.353000
# 25%       1.000000     0 days 00:43:12.011250     0 days 00:42:56.411000
# 50%       2.000000     0 days 01:01:02.911500     0 days 01:09:30.763000
# 75%       3.000000     0 days 01:12:50.067500     0 days 01:12:28.952000
# max       5.000000     0 days 01:27:46.488000     0 days 01:27:19.574000
# std       1.025633  0 days 00:21:11.296627635  0 days 00:18:27.888264513
#
#                      Sector1Time                Sector2Time  \
# count                       1250                       1270
# mean   0 days 00:00:26.277312800  0 days 00:00:28.879967716
# min       0 days 00:00:21.061000     0 days 00:00:23.671000
# 25%       0 days 00:00:24.752000     0 days 00:00:26.758500
# 50%       0 days 00:00:25.809500     0 days 00:00:28.077000
# 75%       0 days 00:00:27.435250     0 days 00:00:29.984750
# max       0 days 00:00:41.378000     0 days 00:00:55.514000
# std    0 days 00:00:03.231378267  0 days 00:00:03.879907359
#
#                      Sector3Time         Sector1SessionTime  \
# count                       1267                       1250
# mean   0 days 00:00:36.100168113     0 days 00:56:04.115688
# min       0 days 00:00:29.890000     0 days 00:06:17.920000
# 25%       0 days 00:00:32.574000     0 days 00:30:00.321250
# 50%       0 days 00:00:34.020000     0 days 00:55:41.126500
# 75%       0 days 00:00:36.470000     0 days 01:20:21.800500
# max       0 days 00:01:31.454000     0 days 01:49:51.762000
# std    0 days 00:00:06.862403727  0 days 00:29:53.631514656
#
#               Sector2SessionTime         Sector3SessionTime      SpeedI1  \
# count                       1270                       1267  1193.000000
# mean   0 days 00:55:44.532354330  0 days 00:56:17.281369376   214.533110
# min       0 days 00:05:12.070000     0 days 00:05:49.775000    86.000000
# 25%       0 days 00:29:16.617250     0 days 00:29:46.319500   200.000000
# 50%       0 days 00:55:57.611000     0 days 00:56:29.335000   221.000000
# 75%       0 days 01:20:40.685500     0 days 01:21:10.954500   235.000000
# max       0 days 01:50:16.062000     0 days 01:50:47.328000   262.000000
# std    0 days 00:30:19.020089701  0 days 00:30:18.826225102    31.238245
#
#            SpeedI2      SpeedFL      SpeedST     TyreLife  \
# count  1270.000000  1225.000000  1270.000000  1272.000000
# mean    266.137008   269.489796   289.821260    12.485063
# min     122.000000   117.000000    65.000000     1.000000
# 25%     268.000000   270.000000   299.000000     6.000000
# 50%     275.000000   274.000000   304.000000    11.000000
# 75%     279.000000   279.000000   309.000000    18.000000
# max     289.000000   300.000000   347.000000    44.000000
# std      27.947662    23.351676    49.014612     8.414129
#
#                     LapStartTime                   LapStartDate     Position
# count                       1272                           1270  1270.000000
# mean   0 days 00:54:49.788138364  2024-06-09 18:53:55.103462144     9.678740
# min       0 days 00:04:05.608000     2024-06-09 18:03:11.605000     1.000000
# 25%       0 days 00:28:22.575500  2024-06-09 18:27:27.439500032     5.000000
# 50%       0 days 00:55:02.171500  2024-06-09 18:54:08.168499968    10.000000
# 75%       0 days 01:19:52.650250  2024-06-09 19:18:58.322500096    14.000000
# max       0 days 01:49:29.708000     2024-06-09 19:48:35.705000    20.000000
# std    0 days 00:30:21.497204231                            NaN     5.403274

# %% [markdown]
# Cleaning data

# %%
print(f"Shape of df_race before cleaning: {df_race.shape}")

df_race_cleaned = df_race.copy()

# Define the time and numeric columns
time_columns = ['Time', 'LapTime', 'PitOutTime', 'PitInTime', 'Sector1Time',
                'Sector2Time', 'Sector3Time', 'Sector1SessionTime', 'Sector2SessionTime',
                'Sector3SessionTime', 'LapStartTime']

# Convert timedelta columns to total seconds (float)
for col in time_columns:
    if col in df_race_cleaned.columns and pd.api.types.is_timedelta64_dtype(df_race_cleaned[col]):
        df_race_cleaned[col + "s"] = df_race_cleaned[col].dt.total_seconds()


# Drop bad laps
mask_clean = (
    df_race_cleaned['IsAccurate'].eq(True) &
    df_race_cleaned['Deleted'].eq(False) &
    df_race_cleaned['TrackStatus'].fillna('1').eq('1') &
    df_race_cleaned['PitInTime'].isna() &
    df_race_cleaned['PitOutTime'].isna() &
    df_race_cleaned['LapTime'].notna()
)

df_race_cleaned = df_race_cleaned[mask_clean].copy()

# Remove extrem lap times
df_race_cleaned = df_race_cleaned[df_race_cleaned['LapTimes'].between(70, 120)]

# Double check missing data
missing_values = df_race_cleaned.isnull().sum()
print("Missing values in each column:")
print(missing_values[missing_values > 0])


print(f"Shape of df_race after cleaning: {df_race_cleaned.shape}")
display(df_race_cleaned.head())
# Out:
# Shape of df_race before cleaning: (1272, 31)
# Missing values in each column:
# PitOutTime     892
# PitInTime      892
# SpeedI1         65
# PitOutTimes    892
# PitInTimes     892
# dtype: int64
# Shape of df_race after cleaning: (892, 42)
#                     Time Driver DriverNumber                LapTime  \
# 1 0 days 00:07:28.538000    VER            1 0 days 00:01:37.672000
# 2 0 days 00:09:04.981000    VER            1 0 days 00:01:36.443000
# 3 0 days 00:10:40.086000    VER            1 0 days 00:01:35.105000
# 4 0 days 00:12:13.945000    VER            1 0 days 00:01:33.859000
# 6 0 days 00:15:17.837000    VER            1 0 days 00:01:31.258000
#
#    LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 1        2.0    1.0        NaT       NaT 0 days 00:00:28.815000
# 2        3.0    1.0        NaT       NaT 0 days 00:00:28.620000
# 3        4.0    1.0        NaT       NaT 0 days 00:00:28.103000
# 4        5.0    1.0        NaT       NaT 0 days 00:00:27.574000
# 6        7.0    1.0        NaT       NaT 0 days 00:00:26.610000
#
#              Sector2Time  ... LapTimes PitOutTimes PitInTimes Sector1Times  \
# 1 0 days 00:00:31.274000  ...   97.672         NaN        NaN       28.815
# 2 0 days 00:00:31.275000  ...   96.443         NaN        NaN       28.620
# 3 0 days 00:00:30.649000  ...   95.105         NaN        NaN       28.103
# 4 0 days 00:00:30.293000  ...   93.859         NaN        NaN       27.574
# 6 0 days 00:00:29.509000  ...   91.258         NaN        NaN       26.610
#
#    Sector2Times  Sector3Times  Sector1SessionTimes  Sector2SessionTimes  \
# 1        31.274        37.583              379.713              410.987
# 2        31.275        36.548              477.190              508.465
# 3        30.649        36.353              573.116              603.765
# 4        30.293        35.992              667.692              697.985
# 6        29.509        35.139              853.221              882.730
#
#   Sector3SessionTimes LapStartTimes
# 1             448.570       350.866
# 2             545.013       448.538
# 3             640.118       544.981
# 4             733.977       640.086
# 6             917.869       826.579
#
# [5 rows x 42 columns]

# %% [markdown]
# Detect outliers

# %%
# IQR Outlier Removal for Lap Times
df_iqr = df_race_cleaned.copy()

# Group by driver so each driver is compared only to their own laps
def remove_outliers_iqr(group, col='LapTimes'):
    Q1 = group[col].quantile(0.25)
    Q3 = group[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return group[(group[col] >= lower_bound) & (group[col] <= upper_bound)]

# Apply to each driver group
df_iqr = df_iqr.groupby('Driver', group_keys=False).apply(remove_outliers_iqr).reset_index(drop=True)

print(f"Before IQR filtering: {df_race_cleaned.shape[0]} laps")
print(f"After IQR filtering: {df_iqr.shape[0]} laps")
print(f"Laps removed: {df_race_cleaned.shape[0] - df_iqr.shape[0]}")

# Quick pace distribution plots before vs after
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.histplot(df_race_cleaned['LapTimes'], bins=30)
plt.title("Before IQR Filtering")
plt.xlabel("Lap Time (s)")

plt.subplot(1,2,2)
sns.histplot(df_iqr['LapTimes'], bins=30, color='green')
plt.title("After IQR Filtering")
plt.xlabel("Lap Time (s)")
plt.tight_layout()
plt.show()
# Out:
# Before IQR filtering: 892 laps
# After IQR filtering: 875 laps
# Laps removed: 17

# %% [markdown]
# Aggregate sector times by driver

# %%
sector_times_2024 = (
    df_iqr.groupby("Driver")
    .agg({
        "Sector1Times": "mean",
        "Sector2Times": "mean",
        "Sector3Times": "mean"
    })
    .reset_index()
)

sector_times_2024["TotalSectorTimes"] = (
    sector_times_2024["Sector1Times"] +
    sector_times_2024["Sector2Times"] +
    sector_times_2024["Sector3Times"]
)

# Calculate the minimum and maximum Total sector times
tst_min = sector_times_2024["TotalSectorTimes"].min()
tst_max = sector_times_2024["TotalSectorTimes"].max()

if tst_max > tst_min:
  sector_times_2024["CleanAirRacePace"] = (tst_max - sector_times_2024["TotalSectorTimes"]) / (tst_max - tst_min)
else:
  sector_times_2024["CleanAirRacePace"] = 0.5

# Map Clean Air Pace to Driver
clean_air_race_pace_map = sector_times_2024.set_index("Driver")["CleanAirRacePace"].to_dict()

display(sector_times_2024)
# Out:
#    Driver  Sector1Times  Sector2Times  Sector3Times  TotalSectorTimes  \
# 0     ALB     26.131343     28.195600     34.109771         88.436714
# 1     ALO     24.995959     27.259367     33.381735         85.637061
# 2     BOT     25.576898     27.829163     33.851061         87.257122
# 3     GAS     25.524720     27.602720     33.582380         86.709820
# 4     HAM     25.001939     27.139490     33.266490         85.407918
# 5     HUL     25.403660     27.490915     33.457723         86.352298
# 6     LEC     26.680852     28.776630     35.038704         90.496185
# 7     MAG     25.271128     27.403128     33.517851         86.192106
# 8     NOR     24.657043     27.077149     33.038809         84.773000
# 9     OCO     25.367340     27.749500     33.739680         86.856520
# 10    PER     26.110812     28.195750     33.866750         88.173313
# 11    PIA     25.005760     27.337380     33.151000         85.494140
# 12    RIC     25.382306     27.604122     33.755245         86.741673
# 13    RUS     25.105130     27.170522     33.221413         85.497065
# 14    SAI     26.430417     28.269694     34.101250         88.801361
# 15    SAR     26.689500     28.645000     34.385062         89.719562
# 16    STR     25.343571     27.529204     33.675286         86.548061
# 17    TSU     25.423780     27.647100     33.790060         86.860940
# 18    VER     24.723571     27.252469     33.254449         85.230490
# 19    ZHO     25.837792     27.969688     34.038729         87.846208
#
#     CleanAirRacePace
# 0           0.359847
# 1           0.849024
# 2           0.565955
# 3           0.661584
# 4           0.889062
# 5           0.724053
# 6           0.000000
# 7           0.752043
# 8           1.000000
# 9           0.635951
# 10          0.405871
# 11          0.873997
# 12          0.656018
# 13          0.873486
# 14          0.296133
# 15          0.135698
# 16          0.689847
# 17          0.635179
# 18          0.920064
# 19          0.463025

# %% [markdown]
# clean air race pac

# %%
# Create clean air race pace
clean_air_race_pace_2024 = clean_air_race_pace_map
print("Clean Air Race Pace (0 -1, Higher = faster) per driver:")
for driver, pace in sorted(clean_air_race_pace_2024.items(), key=lambda kv: -kv[1]):
    print(f"{driver}: {pace:.3f}")
# Out:
# Clean Air Race Pace (0 -1, Higher = faster) per driver:
# NOR: 1.000
# VER: 0.920
# HAM: 0.889
# PIA: 0.874
# RUS: 0.873
# ALO: 0.849
# MAG: 0.752
# HUL: 0.724
# STR: 0.690
# GAS: 0.662
# RIC: 0.656
# OCO: 0.636
# TSU: 0.635
# BOT: 0.566
# ZHO: 0.463
# PER: 0.406
# ALB: 0.360
# SAI: 0.296
# SAR: 0.136
# LEC: 0.000

# %% [markdown]
# Quali data from Canada GP

# %%
# Load 2024 Qualify session
qualify_2024 = fastf1.get_session(2024, 'Canada', 'Q')
qualify_2024.load()

laps_q = qualify_2024.laps.copy()

#Fetch fastest time per driver
drivers = qualify_2024.drivers
qualyTime_2024 = []
for driver_number in drivers:
    driver_info = qualify_2024.get_driver(driver_number)
    driver_abbr = driver_info['Abbreviation']

    driver_laps = laps_q.pick_driver(driver_abbr)
    if driver_laps.empty:
        continue

    best_lap = driver_laps.pick_fastest()
    if best_lap is None or pd.isna(best_lap['LapTime']):
        continue

    qualyTime_2024.append({'Driver': driver_abbr, 'QualifyingTimes': best_lap['LapTime'].total_seconds()})

# Convert to DataFrame
df_qualify = (pd.DataFrame(qualyTime_2024).sort_values(by='QualifyingTimes').reset_index(drop=True))
#
print("2024 Canadian Qualifying Times:")
print(df_qualify.head(10))


# Map to qualifying table
df_qualify['CleanAirRacePace'] = df_qualify['Driver'].map(clean_air_race_pace_2024)

# Keep onl drivers in both
df_qualify_pace = df_qualify.dropna(subset=['CleanAirRacePace']).reset_index(drop=True)
df_qualify_pace = df_qualify_pace.sort_values(by='QualifyingTimes')

print("2024 Canadian Qualifying Times with Clean Air Race Pace:")
print(df_qualify_pace.head(10))

df_qualify_pace.to_csv('2024_Canadian_Qualifying_Times_with_Clean_Air_Race_Pace.csv', index=False)
print('2024_Canadian_Qualifying_Times_with_Clean_Air_Race_Pace.csv is being saved')

# plot Qualifying Times & Clean-Air Race Pace
plt.figure(figsize=(8,6))
plt.scatter(df_qualify_pace['QualifyingTimes'], df_qualify_pace['CleanAirRacePace'])
plt.xlabel('Qualifying Time (s)')
plt.ylabel('Clean-Air Race Pace (index 0-1)')
plt.title('Qualifying Times vs. Clean-Air Race Pace (Canada 2024)')
plt.tight_layout()
plt.show()
# Out:
# core           INFO 	Loading data for Canadian Grand Prix - Qualifying [v3.6.0]
# INFO:fastf1.fastf1.core:Loading data for Canadian Grand Prix - Qualifying [v3.6.0]
# req            INFO 	Using cached data for session_info
# INFO:fastf1.fastf1.req:Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# INFO:fastf1.fastf1.req:Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# INFO:fastf1.fastf1.req:Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# INFO:fastf1.fastf1.req:Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# INFO:fastf1.fastf1.req:Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# INFO:fastf1.fastf1.req:Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# INFO:fastf1.fastf1.core:Processing timing data...
# req            INFO 	Using cached data for car_data
# INFO:fastf1.fastf1.req:Using cached data for car_data
# req            INFO 	Using cached data for position_data
# INFO:fastf1.fastf1.req:Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# INFO:fastf1.fastf1.req:Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# INFO:fastf1.fastf1.req:Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['63', '1', '4', '81', '3', '14', '44', '22', '18', '23', '16', '55', '2', '20', '10', '11', '77', '31', '27', '24']
# INFO:fastf1.fastf1.core:Finished loading data for 20 drivers: ['63', '1', '4', '81', '3', '14', '44', '22', '18', '23', '16', '55', '2', '20', '10', '11', '77', '31', '27', '24']
# 2024 Canadian Qualifying Times:
#   Driver  QualifyingTimes
# 0    RUS           71.742
# 1    HAM           71.979
# 2    VER           72.000
# 3    NOR           72.021
# 4    PIA           72.103
# 5    RIC           72.178
# 6    ALO           72.228
# 7    TSU           72.303
# 8    ALB           72.485
# 9    STR           72.659
# 2024 Canadian Qualifying Times with Clean Air Race Pace:
#   Driver  QualifyingTimes  CleanAirRacePace
# 0    RUS           71.742          0.873486
# 1    HAM           71.979          0.889062
# 2    VER           72.000          0.920064
# 3    NOR           72.021          1.000000
# 4    PIA           72.103          0.873997
# 5    RIC           72.178          0.656018
# 6    ALO           72.228          0.849024
# 7    TSU           72.303          0.635179
# 8    ALB           72.485          0.359847
# 9    STR           72.659          0.689847
# 2024_Canadian_Qualifying_Times_with_Clean_Air_Race_Pace.csv is being saved

# %% [markdown]
# Get weather Data for Canada

# %%
import requests
from datetime import datetime, timezone, timedelta

# Qualifying time session window from FatF1
qualify_start = qualify_2024.session_info['StartDate']
qualify_end = qualify_2024.session_info['EndDate']

def to_utc(dt):
  if getattr(dt, "tzinfo", None) is None:
    return dt.replace(tzinfo=timezone.utc)
  return dt.astimezone(timezone.utc)


qualify_start_utc = to_utc(qualify_start)
qualify_end_utc = to_utc(qualify_end)

# Montréal circuit location
montreal_lat = 45.5016
montreal_lon = -73.567

# Archive vs Forcast
now_utc = datetime.now(timezone.utc)
use_archive = qualify_end_utc < now_utc

api = "https://archive-api.open-meteo.com/v1/archive" if use_archive else "https://api.open-meteo.com/v1/forecast"

params = {
    "latitude": montreal_lat,
    "longitude": montreal_lon,
    "hourly": "temperature_2m,relative_humidity_2m,windspeed_10m,precipitation,precipitation_probability",
    "timezone": "UTC"
}

if use_archive:
    params["start_date"] = qualify_start_utc.strftime("%Y-%m-%d")
    params["end_date"] = qualify_end_utc.strftime("%Y-%m-%d")
else:
    params["forecast_days"] = 7

print("API selected:", api)
print("Archive data used:", use_archive)
print("Params:", {k: v for k, v in params.items() if k in ("start_date","end_date","forecast_days")})

# Request API
response = requests.get(api, params=params, timeout=30)
response.raise_for_status()
data = response.json()

# Hourly DataFrame
hourly = data.get("hourly", {})
df_hourly = pd.DataFrame(hourly)

if df_hourly.empty:
    print("No hourly data available.")
else:
    df_hourly['time'] = pd.to_datetime(df_hourly['time'])
    df_hourly = df_hourly.set_index('time')

# Rename weather columns for consistency
df_hourly = df_hourly.rename(columns={
    "temperature_2m": "Temperature",
    "relative_humidity_2m": "Humidity",
    "windspeed_10m": "WindSpeedKmh",
    "precipitation": "RainMm",
    "precipitation_probability": "RainProbability"
})

# Ensure the required columns exist and numeric
# If None value -> NaN
required_columns = ["Temperature", "Humidity", "WindSpeedKmh", "RainMm", "RainProbability"]
for col in required_columns:
    if col not in df_hourly.columns:
      df_hourly[col] = np.nan
df_hourly[required_columns] = df_hourly[required_columns].apply(pd.to_numeric, errors='coerce')

display(df_hourly.head(20))
# Out:
# API selected: https://archive-api.open-meteo.com/v1/archive
# Archive data used: True
# Params: {'start_date': '2024-06-08', 'end_date': '2024-06-08'}
#                      Temperature  Humidity  WindSpeedKmh  RainMm  \
# time
# 2024-06-08 00:00:00         18.4        72          11.9     0.0
# 2024-06-08 01:00:00         16.3        85           9.5     0.0
# 2024-06-08 02:00:00         15.9        88          13.8     0.0
# 2024-06-08 03:00:00         15.6        89          14.7     0.0
# 2024-06-08 04:00:00         14.9        89          18.9     0.3
# 2024-06-08 05:00:00         14.7        91          16.2     0.2
# 2024-06-08 06:00:00         14.4        93          14.2     0.0
# 2024-06-08 07:00:00         13.9        94          11.4     0.0
# 2024-06-08 08:00:00         13.9        93          13.0     0.0
# 2024-06-08 09:00:00         14.0        92          14.3     0.0
# 2024-06-08 10:00:00         14.1        91          18.1     0.0
# 2024-06-08 11:00:00         14.6        88          18.7     0.0
# 2024-06-08 12:00:00         15.4        82          22.3     0.0
# 2024-06-08 13:00:00         16.6        81          17.9     0.1
# 2024-06-08 14:00:00         17.6        78          19.1     0.0
# 2024-06-08 15:00:00         18.4        73          20.4     0.0
# 2024-06-08 16:00:00         20.0        63          22.4     0.1
# 2024-06-08 17:00:00         20.8        57          22.3     0.1
# 2024-06-08 18:00:00         19.1        63          26.1     0.8
# 2024-06-08 19:00:00         19.4        64          24.1     0.2
#
#                      RainProbability
# time
# 2024-06-08 00:00:00              NaN
# 2024-06-08 01:00:00              NaN
# 2024-06-08 02:00:00              NaN
# 2024-06-08 03:00:00              NaN
# 2024-06-08 04:00:00              NaN
# 2024-06-08 05:00:00              NaN
# 2024-06-08 06:00:00              NaN
# 2024-06-08 07:00:00              NaN
# 2024-06-08 08:00:00              NaN
# 2024-06-08 09:00:00              NaN
# 2024-06-08 10:00:00              NaN
# 2024-06-08 11:00:00              NaN
# 2024-06-08 12:00:00              NaN
# 2024-06-08 13:00:00              NaN
# 2024-06-08 14:00:00              NaN
# 2024-06-08 15:00:00              NaN
# 2024-06-08 16:00:00              NaN
# 2024-06-08 17:00:00              NaN
# 2024-06-08 18:00:00              NaN
# 2024-06-08 19:00:00              NaN

# %% [markdown]
# Adjust qualifying time based on weather conditions

# %%
# Merge weather conditions

# Best start time lap for each driver
# The 'LapStartDate' is already available and in datetime format from the previous steps.
best_idx = laps_q.groupby("Driver")["LapTime"].idxmin()
best_lap_time = laps_q.loc[best_idx, ["Driver", "LapTime", "LapStartDate"]].reset_index(drop=True)

# Ensure the type is datetime for df_hourly index
df_hourly.index = pd.to_datetime(df_hourly.index)

# Merge driver's best lap with weather condition
best_lap_weather = []
for index, row in best_lap_time.iterrows():
    driver = row['Driver']
    lap_datetime = row['LapStartDate']

    # Find the nearest weather data based on LapStartDate (datetime)
    try:
        nearest_weather_time = df_hourly.index.get_indexer([lap_datetime], method='nearest')[0]
        weather_data = df_hourly.iloc[nearest_weather_time]
        best_lap_weather.append({
            "Driver": driver,
            "Temperature": weather_data["Temperature"],
            "Humidity": weather_data["Humidity"],
            "WindSpeedKmh": weather_data["WindSpeedKmh"],
            "RainMm": weather_data.get("RainMm", 0.0),
            "RainProbability": weather_data.get("RainProbability", 0.0)
        })
    except IndexError:
        # Handle cases where no nearest time is found
        print(f"Warning: No weather data found near {lap_datetime} for driver {driver}")
        best_lap_weather.append({
            'Driver': driver,
            'Temperature': None,
            'Humidity': None,
            'WindSpeedKmh': None,
            'RainMm': None,
            'RainProbability': None
        })


df_weather = pd.DataFrame(best_lap_weather)

# Merge with df_qualify_pace
final_df = pd.merge(df_qualify_pace, df_weather, on='Driver', how='left')


# make sure the rain, rain probability is numeric
final_df['RainMm'] = pd.to_numeric(final_df['RainMm'], errors='coerce').fillna(0)
final_df['RainProbability'] = pd.to_numeric(final_df['RainProbability'], errors='coerce').fillna(0)

# Add rain flag
final_df['is_rain'] = final_df['RainMm'].apply(lambda x: 1 if x and x > 0.05 else 0)

#Preview final dataset
display(final_df.head(20))
# Out:
#    Driver  QualifyingTimes  CleanAirRacePace  Temperature  Humidity  \
# 0     RUS           71.742          0.873486         20.4      59.0
# 1     HAM           71.979          0.889062         20.4      59.0
# 2     VER           72.000          0.920064         20.4      59.0
# 3     NOR           72.021          1.000000         20.4      59.0
# 4     PIA           72.103          0.873997         20.4      59.0
# 5     RIC           72.178          0.656018         20.4      59.0
# 6     ALO           72.228          0.849024         20.4      59.0
# 7     TSU           72.303          0.635179         20.4      59.0
# 8     ALB           72.485          0.359847         20.4      59.0
# 9     STR           72.659          0.689847         20.4      59.0
# 10    LEC           72.691          0.000000         20.4      59.0
# 11    SAI           72.728          0.296133         20.4      59.0
# 12    SAR           72.736          0.135698         20.4      59.0
# 13    MAG           72.916          0.752043         20.1      63.0
# 14    GAS           72.940          0.661584         20.4      59.0
# 15    PER           73.326          0.405871         20.1      63.0
# 16    BOT           73.366          0.565955         20.1      63.0
# 17    OCO           73.435          0.635951         20.1      63.0
# 18    HUL           73.978          0.724053         20.1      63.0
# 19    ZHO           74.292          0.463025         20.1      63.0
#
#     WindSpeedKmh  RainMm  RainProbability  is_rain
# 0           26.3     0.0              0.0        0
# 1           26.3     0.0              0.0        0
# 2           26.3     0.0              0.0        0
# 3           26.3     0.0              0.0        0
# 4           26.3     0.0              0.0        0
# 5           26.3     0.0              0.0        0
# 6           26.3     0.0              0.0        0
# 7           26.3     0.0              0.0        0
# 8           26.3     0.0              0.0        0
# 9           26.3     0.0              0.0        0
# 10          26.3     0.0              0.0        0
# 11          26.3     0.0              0.0        0
# 12          26.3     0.0              0.0        0
# 13          24.9     0.2              0.0        1
# 14          26.3     0.0              0.0        0
# 15          24.9     0.2              0.0        1
# 16          24.9     0.2              0.0        1
# 17          24.9     0.2              0.0        1
# 18          24.9     0.2              0.0        1
# 19          24.9     0.2              0.0        1

# %%
# Get constructor standings for the 2024 Canadian GP
# Access constructor standings from the results attribute of the session
# The results attribute is a DataFrame containing driver results, which includes constructor info and points
results_df = race_2024.results.copy()

# Filter for constructors and their points
constructor_standings_df = results_df[['TeamName', 'Points']].groupby('TeamName').sum().reset_index()

# Create dict of team points
team_points = {row['TeamName']: row['Points'] for _, row in constructor_standings_df.iterrows()}

# Normalize to max points
max_points = max(team_points.values())
team_performance_score = {team: pts / max_points for team, pts in team_points.items()}

print(team_performance_score)

# Map driver to team
driver_to_team = results_df.set_index('Abbreviation')['TeamName'].to_dict()

# Add team info to final data set
final_df['Team'] = final_df['Driver'].map(driver_to_team)

# Add teamm performance score
final_df['TeamPerformanceScore'] = final_df['Team'].map(team_performance_score)

# Calculate Averag Position from race (quali pos - finish pos)
pos_df = results_df[['Abbreviation', 'GridPosition','Position']].copy()
# Ensure numeric values
pos_df['GridPosition'] = pd.to_numeric(pos_df['GridPosition'], errors='coerce')
pos_df['Position'] = pd.to_numeric(pos_df['Position'], errors='coerce')
pos_df['AveragePositionChange'] = pos_df['GridPosition'] - pos_df['Position']

# Map to final data set
pos_change_map = pos_df.set_index('Abbreviation')['AveragePositionChange'].to_dict()
final_df['AveragePositionChange'] = final_df['Driver'].map(pos_change_map)

# Add GridPosition and FinishPosition to final Data set (final_df)
grid_map = pos_df.set_index('Abbreviation')['GridPosition'].to_dict()
final_df['GridPosition'] = final_df['Driver'].map(grid_map)
finish_map = pos_df.set_index('Abbreviation')['Position'].to_dict()
final_df['FinishPosition'] = final_df['Driver'].map(finish_map)

# Filter and keep only required columns
keep_cols = ['Driver', 'Team', 'QualifyingTimes', 'GridPosition', 'TeamPerformanceScore',
             'Temperature', 'RainMm', 'RainProbability', 'FinishPosition']
if 'CleanAirRacePace' in final_df.columns:
  keep_cols.append('CleanAirRacePace')

# Final data set
final_df = final_df[[c for c in keep_cols if c in final_df.columns]]


# Preview final dataset
display(final_df.head(20))
# Out:
# {'Alpine': 0.10714285714285714, 'Aston Martin': 0.5, 'Ferrari': 0.0, 'Haas F1 Team': 0.0, 'Kick Sauber': 0.0, 'McLaren': 1.0, 'Mercedes': 1.0, 'RB': 0.14285714285714285, 'Red Bull Racing': 0.8928571428571429, 'Williams': 0.0}
#    Driver             Team  QualifyingTimes  GridPosition  \
# 0     RUS         Mercedes           71.742           1.0
# 1     HAM         Mercedes           71.979           7.0
# 2     VER  Red Bull Racing           72.000           2.0
# 3     NOR          McLaren           72.021           3.0
# 4     PIA          McLaren           72.103           4.0
# 5     RIC               RB           72.178           5.0
# 6     ALO     Aston Martin           72.228           6.0
# 7     TSU               RB           72.303           8.0
# 8     ALB         Williams           72.485          10.0
# 9     STR     Aston Martin           72.659           9.0
# 10    LEC          Ferrari           72.691          11.0
# 11    SAI          Ferrari           72.728          12.0
# 12    SAR         Williams           72.736          13.0
# 13    MAG     Haas F1 Team           72.916          14.0
# 14    GAS           Alpine           72.940          15.0
# 15    PER  Red Bull Racing           73.326          16.0
# 16    BOT      Kick Sauber           73.366          19.0
# 17    OCO           Alpine           73.435          18.0
# 18    HUL     Haas F1 Team           73.978          17.0
# 19    ZHO      Kick Sauber           74.292          20.0
#
#     TeamPerformanceScore  Temperature  RainMm  RainProbability  \
# 0               1.000000         20.4     0.0              0.0
# 1               1.000000         20.4     0.0              0.0
# 2               0.892857         20.4     0.0              0.0
# 3               1.000000         20.4     0.0              0.0
# 4               1.000000         20.4     0.0              0.0
# 5               0.142857         20.4     0.0              0.0
# 6               0.500000         20.4     0.0              0.0
# 7               0.142857         20.4     0.0              0.0
# 8               0.000000         20.4     0.0              0.0
# 9               0.500000         20.4     0.0              0.0
# 10              0.000000         20.4     0.0              0.0
# 11              0.000000         20.4     0.0              0.0
# 12              0.000000         20.4     0.0              0.0
# 13              0.000000         20.1     0.2              0.0
# 14              0.107143         20.4     0.0              0.0
# 15              0.892857         20.1     0.2              0.0
# 16              0.000000         20.1     0.2              0.0
# 17              0.107143         20.1     0.2              0.0
# 18              0.000000         20.1     0.2              0.0
# 19              0.000000         20.1     0.2              0.0
#
#     FinishPosition  CleanAirRacePace
# 0              3.0          0.873486
# 1              4.0          0.889062
# 2              1.0          0.920064
# 3              2.0          1.000000
# 4              5.0          0.873997
# 5              8.0          0.656018
# 6              6.0          0.849024
# 7             14.0          0.635179
# 8             17.0          0.359847
# 9              7.0          0.689847
# 10            19.0          0.000000
# 11            16.0          0.296133
# 12            20.0          0.135698
# 13            12.0          0.752043
# 14             9.0          0.661584
# 15            18.0          0.405871
# 16            13.0          0.565955
# 17            10.0          0.635951
# 18            11.0          0.724053
# 19            15.0          0.463025

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.impute import SimpleImputer
import time

# Features
features = ['QualifyingTimes', 'GridPosition', 'TeamPerformanceScore',
            'Temperature', 'RainMm', 'RainProbability']
x = final_df[features].copy()

# Target (FinishPosition: lower = better)
y = pd.to_numeric(final_df['FinishPosition'], errors='coerce')

# Drop rows with missing target
keep = y.notna()
x,y = x.loc[keep], y.loc[keep].astype(float)

# Impute features (median)
imputer = SimpleImputer(strategy="median")
x_imputed = imputer.fit_transform(x)

# Split (70/30)
x_train, x_test, y_train, y_test = train_test_split(x_imputed, y, test_size=0.3, random_state=37)

# Models
models = {
    "Linear Regression": LinearRegression(),
    "RandomForest": RandomForestRegressor(random_state=37),
    "GradientBoosting": GradientBoostingRegressor(random_state=37),
    "XGBoost": XGBRegressor(random_state=37)
}

rows, fitted = [], {}
for name, model in models.items():
    start_time = time.time()
    model.fit(x_train, y_train)          # <-- use x_train
    pred = model.predict(x_test)         # <-- use x_test
    rows.append({
        "Model": name,
        "RMSE": float(np.sqrt(mean_squared_error(y_test, pred))),
        "MAE": float(mean_absolute_error(y_test, pred)),
        "R²": float(r2_score(y_test, pred)),
        "Time (s)": round(time.time() - start_time, 3)
    })
    fitted[name] = model

df_results = pd.DataFrame(rows).sort_values(["MAE", "RMSE"])
display(df_results)

best_model_name = df_results.iloc[0]["Model"]
y_pred_test = fitted[best_model_name].predict(x_test)
print(f"Best model: {best_model_name}")
# Out:
#                Model      RMSE       MAE        R²  Time (s)
# 3            XGBoost  2.265625  1.990741  0.349331     0.021
# 1       RandomForest  3.017933  2.521667 -0.154525     0.196
# 2   GradientBoosting  3.294321  2.846770 -0.375675     0.081
# 0  Linear Regression  6.293802  4.347620 -4.021232     0.003
# Best model: XGBoost

# %% [markdown]
# Review the table above

# %%
# Features
features = ['QualifyingTimes', 'GridPosition', 'TeamPerformanceScore',
            'Temperature', 'RainMm', 'RainProbability']
x = final_df[features].copy()

# Target (FinishPosition: lower = better)
y = pd.to_numeric(final_df['FinishPosition'], errors='coerce')

# Drop rows with missing target
keep = y.notna()
x,y = x.loc[keep], y.loc[keep].astype(float)

# Impute features (median)
imputer = SimpleImputer(strategy="median")
x_imputed = imputer.fit_transform(x)

model = XGBRegressor(random_state=37)
model.fit(x_imputed, y)


final_df.loc[keep, "PredictedFinish"] = model.predict(x_imputed)

# Sort predicted finishing order
predicted = final_df.loc[keep, ["Driver", "PredictedFinish"]].sort_values("PredictedFinish").reset_index(drop=True)

display(predicted.head(20))
# Out:
#    Driver  PredictedFinish
# 0     VER         1.001623
# 1     NOR         2.000232
# 2     RUS         2.999714
# 3     HAM         4.000081
# 4     PIA         4.999857
# 5     ALO         5.999986
# 6     STR         7.001064
# 7     RIC         8.000409
# 8     GAS         9.001397
# 9     OCO        10.000180
# 10    HUL        11.001056
# 11    MAG        11.999805
# 12    BOT        13.000072
# 13    TSU        13.998874
# 14    ZHO        14.999101
# 15    SAI        16.001650
# 16    ALB        17.000256
# 17    PER        17.998529
# 18    LEC        18.998312
# 19    SAR        19.997797

# %% [markdown]
# Plot Feature importance

# %%
# Feature importance for the XGBRegressor
feature_names = list(x.columns)
feature_importance = model.feature_importances_

plt.figure(figsize=(8,5))
plt.barh(feature_names, feature_importance)
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.title("XGBRegressor — Feature Importance")
plt.show()

# %% [markdown]
# Evaluation

# %%
# Compare table (Actual vs Predicted)
eval_df = final_df.loc[final_df['FinishPosition'].notna(), [
    'Driver','Team','GridPosition','QualifyingTimes','Temperature','RainMm','RainProbability',
    'FinishPosition','PredictedFinish'
]].copy()

eval_df['Error'] = eval_df['PredictedFinish'] - eval_df['FinishPosition']
final_df["AbsError"] = eval_df["Error"].abs()

# Display predicted order with errors
display(eval_df.sort_values("PredictedFinish").reset_index(drop=True))

# Metrics Summary
rmse = float(np.sqrt(mean_squared_error(eval_df['FinishPosition'], eval_df['PredictedFinish'])))
mae  = float(mean_absolute_error(eval_df['FinishPosition'], eval_df['PredictedFinish']))
r2   = float(r2_score(eval_df['FinishPosition'], eval_df['PredictedFinish']))
print(f"Summary — RMSE: {rmse:.3f} | MAE: {mae:.3f} | R²: {r2:.3f}")

# Baseline: predict finish equals grid position
baseline_pred = eval_df['GridPosition'].values
rmse_base = float(np.sqrt(mean_squared_error(eval_df['FinishPosition'], baseline_pred)))
mae_base  = float(mean_absolute_error(eval_df['FinishPosition'], baseline_pred))
print(f"Baseline (GridPosition) — RMSE: {rmse_base:.3f} | MAE: {mae_base:.3f}")

# true generalization metrics using the previus test
try:
    test_rmse = float(np.sqrt(mean_squared_error(y_test, y_pred_test)))
    test_mae  = float(mean_absolute_error(y_test, y_pred_test))
    test_r2   = float(r2_score(y_test, y_pred_test))
    print(f"Test set (hold-out) — RMSE: {test_rmse:.3f} | MAE: {test_mae:.3f} | R²: {test_r2:.3f}")
except NameError:
    print("Note: y_test / y_pred_test not found. Re-run the edited Cell 12 first.")
# Out:
#    Driver             Team  GridPosition  QualifyingTimes  Temperature  \
# 0     VER  Red Bull Racing           2.0           72.000         20.4
# 1     NOR          McLaren           3.0           72.021         20.4
# 2     RUS         Mercedes           1.0           71.742         20.4
# 3     HAM         Mercedes           7.0           71.979         20.4
# 4     PIA          McLaren           4.0           72.103         20.4
# 5     ALO     Aston Martin           6.0           72.228         20.4
# 6     STR     Aston Martin           9.0           72.659         20.4
# 7     RIC               RB           5.0           72.178         20.4
# 8     GAS           Alpine          15.0           72.940         20.4
# 9     OCO           Alpine          18.0           73.435         20.1
# 10    HUL     Haas F1 Team          17.0           73.978         20.1
# 11    MAG     Haas F1 Team          14.0           72.916         20.1
# 12    BOT      Kick Sauber          19.0           73.366         20.1
# 13    TSU               RB           8.0           72.303         20.4
# 14    ZHO      Kick Sauber          20.0           74.292         20.1
# 15    SAI          Ferrari          12.0           72.728         20.4
# 16    ALB         Williams          10.0           72.485         20.4
# 17    PER  Red Bull Racing          16.0           73.326         20.1
# 18    LEC          Ferrari          11.0           72.691         20.4
# 19    SAR         Williams          13.0           72.736         20.4
#
#     RainMm  RainProbability  FinishPosition  PredictedFinish     Error
# 0      0.0              0.0             1.0         1.001623  0.001623
# 1      0.0              0.0             2.0         2.000232  0.000232
# 2      0.0              0.0             3.0         2.999714 -0.000286
# 3      0.0              0.0             4.0         4.000081  0.000081
# 4      0.0              0.0             5.0         4.999857 -0.000143
# 5      0.0              0.0             6.0         5.999986 -0.000014
# 6      0.0              0.0             7.0         7.001064  0.001064
# 7      0.0              0.0             8.0         8.000409  0.000409
# 8      0.0              0.0             9.0         9.001397  0.001397
# 9      0.2              0.0            10.0        10.000180  0.000180
# 10     0.2              0.0            11.0        11.001056  0.001056
# 11     0.2              0.0            12.0        11.999805 -0.000195
# 12     0.2              0.0            13.0        13.000072  0.000072
# 13     0.0              0.0            14.0        13.998874 -0.001126
# 14     0.2              0.0            15.0        14.999101 -0.000899
# 15     0.0              0.0            16.0        16.001650  0.001650
# 16     0.0              0.0            17.0        17.000256  0.000256
# 17     0.2              0.0            18.0        17.998529 -0.001471
# 18     0.0              0.0            19.0        18.998312 -0.001688
# 19     0.0              0.0            20.0        19.997797 -0.002203
# Summary — RMSE: 0.001 | MAE: 0.001 | R²: 1.000
# Baseline (GridPosition) — RMSE: 4.733 | MAE: 4.000
# Test set (hold-out) — RMSE: 2.266 | MAE: 1.991 | R²: 0.349

# %% [markdown]
# Predict 2025

# %%
# Use model trained on 2024 to predict 2025 results

# Load 29025 Quslifying
race_2025 = fastf1.get_session(2025, 'Canada', 'Q') # Q = Qualify
race_2025.load()

laps_q_target = race_2025.laps.copy()

drivers = []
for driver_number in race_2025.drivers:
    driver_info = race_2025.get_driver(driver_number)
    driver_abbr = driver_info['Abbreviation']

    driverlaps = laps_q_target.pick_driver(driver_abbr)
    if driverlaps.empty:
        continue

    best_lap = driverlaps.pick_fastest()
    if best_lap is None or pd.isna(best_lap['LapTime']):
        continue

    drivers.append({
        'Driver': driver_abbr,
        'Team': best_lap.get('Team', None),
        'QualifyingTimes': float(best_lap['LapTime'].total_seconds()),
        'LapStartDate': best_lap['LapStartDate']
        })

final_df_2025 = pd.DataFrame(drivers).sort_values(by='QualifyingTimes').reset_index(drop=True)

# Grid position
final_df_2025['GridPosition'] = final_df_2025['QualifyingTimes'].rank(method='first').astype(int)

# Weather
qualify_date = race_2025.event['EventDate'].date()

# Montreal coordinates
montreal_lat = 45.5016
montreal_lon = -73.567

api = "https://archive-api.open-meteo.com/v1/archive"

params = {
    "latitude": montreal_lat,
    "longitude": montreal_lon,
    "start_date": str(qualify_date),
    "end_date":(qualify_date),
    "hourly": "temperature_2m,relative_humidity_2m,windspeed_10m,precipitation,precipitation_probability",
    "timezone": "UTC"
}

# Request API
response = requests.get(api, params=params, timeout=30)
response.raise_for_status()
data = response.json()

# Hourly DataFrame
hourly = data.get("hourly", {})
df_hourly_2025 = pd.DataFrame(hourly)

if df_hourly_2025.empty:
    print("No hourly data available.")
else:
    df_hourly_2025['time'] = pd.to_datetime(df_hourly_2025['time'])
    df_hourly_2025 = df_hourly_2025.set_index('time')

# Rename weather columns for consistency
df_hourly_2025 = df_hourly_2025.rename(columns={
    "temperature_2m": "Temperature",
    "relative_humidity_2m": "Humidity",
    "windspeed_10m": "WindSpeedKmh",
    "precipitation": "RainMm",
    "precipitation_probability": "RainProbability"
})

best_lap_weather = []
for index, row in final_df_2025.iterrows():
    driver = row['Driver']
    lap_datetime = pd.to_datetime(row['LapStartDate']) # Keep timezone-naive

    index = df_hourly_2025.index.get_indexer([lap_datetime], method='nearest')[0]
    weather_data = df_hourly_2025.iloc[index]
    best_lap_weather.append({
        "Driver": driver,
        "Temperature": weather_data.get("Temperature", np.nan),
        "RainMm": weather_data.get("RainMm", 0.0),
        "RainProbability": weather_data["RainProbability"] if "RainProbability" in weather_data else 0.0,

    })

weather_df_2025 = pd.DataFrame(best_lap_weather)

# TeamPerformance: using
teamPS_median = float(np.median(list(team_performance_score.values()))) if len(team_performance_score) else 0.5
final_df_2025['TeamPerformanceScore'] = final_df_2025['Team'].map(team_performance_score).fillna(teamPS_median)

# -------- Merge features and predict ------
final_df_2025 = final_df_2025.merge(weather_df_2025, on='Driver', how='left')

# Ensure columns are exist and numeric
features = ['QualifyingTimes', 'GridPosition', 'TeamPerformanceScore',
            'Temperature', 'RainMm', 'RainProbability']
for col in ['Temperature', 'RainMm', 'RainProbability']:
        final_df_2025[col] = pd.to_numeric(final_df_2025[col], errors='coerce')
final_df_2025[['RainMm','RainProbability']] = final_df_2025[['RainMm','RainProbability']].fillna(0)

x_2025 = final_df_2025[features].copy()
x_2025_imputed = imputer.transform(x_2025)

final_df_2025["PredictedFinish"] = model.predict(x_2025_imputed)

# Show prediction
predicted_2025 = final_df_2025[['Driver','PredictedFinish']].sort_values('PredictedFinish').reset_index(drop=True)
print(f"Predicted finishing order")
display(predicted_2025)

# Save prediction on csv file
predicted_2025.to_csv("predicted_order_2025_canada.csv", index=False)
print("Saved predicted order to predicted_order_2025_canada.csv")
# Out:
# core           INFO 	Loading data for Canadian Grand Prix - Qualifying [v3.6.0]
# INFO:fastf1.fastf1.core:Loading data for Canadian Grand Prix - Qualifying [v3.6.0]
# req            INFO 	Using cached data for session_info
# INFO:fastf1.fastf1.req:Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# INFO:fastf1.fastf1.req:Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# INFO:fastf1.fastf1.req:Using cached data for session_status_data
# req            INFO 	Using cached data for track_status_data
# INFO:fastf1.fastf1.req:Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# INFO:fastf1.fastf1.req:Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# INFO:fastf1.fastf1.req:Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# INFO:fastf1.fastf1.core:Processing timing data...
# req            INFO 	Using cached data for car_data
# INFO:fastf1.fastf1.req:Using cached data for car_data
# req            INFO 	Using cached data for position_data
# INFO:fastf1.fastf1.req:Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# INFO:fastf1.fastf1.req:Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# INFO:fastf1.fastf1.req:Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['63', '1', '81', '12', '44', '14', '4', '16', '6', '23', '22', '43', '27', '87', '31', '5', '55', '18', '30', '10']
# INFO:fastf1.fastf1.core:Finished loading data for 20 drivers: ['63', '1', '81', '12', '44', '14', '4', '16', '6', '23', '22', '43', '27', '87', '31', '5', '55', '18', '30', '10']
# Predicted finishing order
#    Driver  PredictedFinish
# 0     VER         1.905583
# 1     PIA         2.999525
# 2     RUS         2.999714
# 3     ALO         3.025706
# 4     ANT         3.999065
# 5     NOR         4.000081
# 6     TSU         4.474245
# 7     HAM         5.956504
# 8     LEC         5.957600
# 9     HAD         5.957600
# 10    ALB         6.265309
# 11    COL         7.355747
# 12    HUL         8.310206
# 13    LAW        12.920306
# 14    STR        12.946174
# 15    GAS        14.906522
# 16    BOR        17.001299
# 17    OCO        17.001299
# 18    BEA        17.001299
# 19    SAI        17.001299
# Saved predicted order to predicted_order_2025_canada.csv

# %% [markdown]
# Compare modles' results with actual reults

# %%
# Fetch 2025 results
results_2025 = []

for driver_number in race_2025.drivers:
    driver_info = race_2025.get_driver(driver_number)
    driver_abbr = driver_info['Abbreviation']
    pos = race_2025.results.loc[driver_number]['Position']
    results_2025.append({
        'Driver': driver_abbr,
        'ActualFinish': int(pos)
    })
actual_2025_results = pd.DataFrame(results_2025)

comapre_results = predicted_2025.merge(actual_2025_results, on='Driver', how='left')
comapre_results['Error'] = comapre_results['PredictedFinish'] - comapre_results['ActualFinish']

# Calculate errors
rmse_2025 = float(np.sqrt(mean_squared_error(comapre_results['ActualFinish'], comapre_results['PredictedFinish'])))
mae_2025  = float(mean_absolute_error(comapre_results['ActualFinish'], comapre_results['PredictedFinish']))

print(f"Canadian GP 2025 - RMSE: {rmse_2025:.3f}, MAE: {mae_2025:.3f}")
display(comapre_results)

# ------ Plot the results -------
# Predicted vs Actual
plt.figure(figsize=(6,6))
plt.scatter(comapre_results["ActualFinish"], comapre_results["PredictedFinish"])
mn = 1
mx = int(np.ceil(max(comapre_results[["ActualFinish","PredictedFinish"]].max())))
plt.plot([mn, mx], [mn, mx], linestyle="--")
plt.xlabel("Actual Finish (1 = best)")
plt.ylabel("Predicted Finish (lower = better)")
plt.title("Canadian GP 2025 — Predicted vs Actual")
plt.tight_layout()
plt.show()

print("")

# Error by Driver
err_sorted = comapre_results.sort_values("Error")
plt.figure(figsize=(9,4.5))
plt.bar(err_sorted["Driver"], err_sorted["Error"])
plt.axhline(0, linestyle="--")
plt.ylabel("Error (Predicted - Actual)")
plt.title("Prediction Error by Driver")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Canadian GP 2025 - RMSE: 3.455, MAE: 2.797
#    Driver  PredictedFinish  ActualFinish     Error
# 0     VER         1.905583             2 -0.094417
# 1     PIA         2.999525             3 -0.000475
# 2     RUS         2.999714             1  1.999714
# 3     ALO         3.025706             6 -2.974294
# 4     ANT         3.999065             4 -0.000935
# 5     NOR         4.000081             7 -2.999919
# 6     TSU         4.474245            11 -6.525755
# 7     HAM         5.956504             5  0.956504
# 8     LEC         5.957600             8 -2.042400
# 9     HAD         5.957600             9 -3.042400
# 10    ALB         6.265309            10 -3.734691
# 11    COL         7.355747            12 -4.644253
# 12    HUL         8.310206            13 -4.689794
# 13    LAW        12.920306            19 -6.079694
# 14    STR        12.946174            18 -5.053826
# 15    GAS        14.906522            20 -5.093478
# 16    BOR        17.001299            16  1.001299
# 17    OCO        17.001299            15  2.001299
# 18    BEA        17.001299            14  3.001299
# 19    SAI        17.001299            17  0.001299
